# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1- We want to know whether men and women choose different jobs. (and if so which job)

# %% [markdown]
# another formualtion of the question is that is there is a relation between the gender and the job type

# %% [markdown]
# ----
# ### Hypothesis testing
# <pre>If I want to apply hypothesis testing, I will use the following hypothesis:
# H_0-> the number of women and men in each job type is equal (The ratio between male and female is 1 in the sane Job type)
# H_1-> there at least one job that the number of the females and males differ (The ratio between male and female is not 1)
# is it applicale ?
# </pre>
#
# <pre>
# - The proportion of the female and male freq(male)/freq(female) for each job type
#     If I want to apply this Hypothesis testing, It will be made for each job type,
#     and the result will be a list of p-values for each job type
#     Is this answering my question ?
# - No because the effect of the job type is not considered, and the result will be a list of p-values for each job type
# </pre>
# ----

# %% [markdown]
# if we constructed table for each job and the number of Males and females in each job
# |Job|Male|Female|
# |---|---|---|
# |Job1|10|20|
#
# we can use chi-square test to test whether males and females choose different jobs or not

# %%
df = pd.read_csv('Glassdoor Gender Pay Gap.csv')
df.head()
# Out:
#               JobTitle  Gender  Age  PerfEval Education            Dept  \
# 0     Graphic Designer  Female   18         5   College      Operations
# 1    Software Engineer    Male   21         5   College      Management
# 2  Warehouse Associate  Female   19         4       PhD  Administration
# 3    Software Engineer    Male   20         5   Masters           Sales
# 4     Graphic Designer    Male   26         5   Masters     Engineering
#
#    Seniority  BasePay  Bonus
# 0          2    42363   9938
# 1          5   108476  11128
# 2          5    90208   9268
# 3          4   108080  10154
# 4          5    99464   9319

# %%
df['Gender']=df['Gender'].apply(lambda x: 1 if x =='Male' else 0)
df['Male']=df['Gender'].apply(lambda x: 1 if x ==1 else 0)
df['Female']=df['Gender'].apply(lambda x: 1 if x ==0 else 0)

# %%
Observed=df.groupby(['JobTitle'])[['Male','Female']].sum()

# %%
Observed
# Out:
#                      Male  Female
# JobTitle
# Data Scientist         54      53
# Driver                 45      46
# Financial Analyst      58      49
# Graphic Designer       50      48
# IT                     46      50
# Manager                72      18
# Marketing Associate    11     107
# Sales Associate        51      43
# Software Engineer     101       8
# Warehouse Associate    44      46

# %%
plt.figure(figsize=(20,15))
sns.countplot(data =df , x= 'JobTitle', hue='Gender')
# Out:
# <Axes: xlabel='JobTitle', ylabel='count'>
